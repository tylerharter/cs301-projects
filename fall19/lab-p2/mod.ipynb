# %%
0 % 12

# %%
1 % 12

# %%
2 % 12

# %%
3 % 12

# %%
4 % 12

# %%
5 % 12

# %%
6 % 12

# %%
7 % 12

# %%
8 % 12

# %%
9 % 12

# %%
10 % 12

# %%
11 % 12

# %%
# wraps back to 0!
12 % 12

# %%
13 % 12

# %%
14 % 12

# %%
15 % 12

# %%
16 % 12

# %%
17 % 12

# %%
18 % 12

# %%
19 % 12

# %%
20 % 12

# %%
21 % 12

# %%
22 % 12

# %%
23 % 12

# %%
# wraps back to 0!
24 % 12

# %%
25 % 12

# %%
26 % 12
